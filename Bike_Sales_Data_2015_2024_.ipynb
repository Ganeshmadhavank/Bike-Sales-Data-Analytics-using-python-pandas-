# %% [markdown]
# <a href="https://colab.research.google.com/github/Ganeshmadhavank/Bike-Sales-Data-Analytics-using-python-pandas-/blob/main/Bike_Sales_Data_2015_2024_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Set From -[Bike Sales Data](https://docs.google.com/spreadsheets/d/1xMSX4esYjRaLCnCDdzNj7KQ_W3qW3L_79ZpLKfuQlO8/edit?usp=sharing)

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("ak0212/indian-bike-sales-dataset")

print("D:\Bike Sales Data:", path)
# Out:
# ...
# 100%|██████████| 266k/266k [00:00<00:00, 621kB/s]
# Extracting files...
# D:\Bike Sales Data: /root/.cache/kagglehub/datasets/ak0212/indian-bike-sales-dataset/versions/1

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv("/content/bike_sales_india.csv")

# %%
df2=df.copy()

# %%
df2.head(8)
# Out:
#             State  Avg Daily Distance (km)          Brand          Model  \
# 0       Karnataka                    68.84  Royal Enfield     Hunter 350
# 1       Rajasthan                    23.80          Bajaj    Dominar 400
# 2  Madhya Pradesh                    27.67            KTM       125 Duke
# 3       Karnataka                    62.85       Kawasaki      Ninja 300
# 4  Madhya Pradesh                    10.62         Yamaha          FZ V3
# 5     Maharashtra                    47.71           Hero  Splendor Plus
# 6     Maharashtra                    77.95  Royal Enfield     Meteor 350
# 7      Tamil Nadu                    11.57       Kawasaki       Vulcan S
#
#    Price (INR)  Year of Manufacture  Engine Capacity (cc) Fuel Type  \
# 0       252816                 2021                   672  Electric
# 1       131100                 2020                   769    Hybrid
# 2       201016                 2020                   216    Hybrid
# ...

# %%
df2.tail()
# Out:
#                State  Avg Daily Distance (km)          Brand        Model  \
# 9995         Gujarat                    67.72           Hero  Passion Pro
# 9996           Delhi                    19.94          Bajaj       CT 100
# 9997     West Bengal                    79.95          Bajaj   Pulsar 150
# 9998  Madhya Pradesh                    16.07          Honda          Dio
# 9999     West Bengal                    51.16  Royal Enfield  Classic 350
#
#       Price (INR)  Year of Manufacture  Engine Capacity (cc) Fuel Type  \
# 9995        95040                 2024                   297  Electric
# 9996       110369                 2015                   210    Hybrid
# 9997       313806                 2018                   267    Hybrid
# 9998       204068                 2018                   856  Electric
# 9999       323583                 2018                   529    Petrol
#
#       Mileage (km/l) Owner Type  Registration Year Insurance Status  \
# ...

# %%
df2.isna().sum()
# Out:
# State                      0
# Avg Daily Distance (km)    0
# Brand                      0
# Model                      0
# Price (INR)                0
# Year of Manufacture        0
# Engine Capacity (cc)       0
# Fuel Type                  0
# Mileage (km/l)             0
# Owner Type                 0
# Registration Year          0
# Insurance Status           0
# Seller Type                0
# Resale Price (INR)         0
# City Tier                  0
# dtype: int64

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   State                    10000 non-null  object
#  1   Avg Daily Distance (km)  10000 non-null  float64
#  2   Brand                    10000 non-null  object
#  3   Model                    10000 non-null  object
#  4   Price (INR)              10000 non-null  int64
#  5   Year of Manufacture      10000 non-null  int64
#  6   Engine Capacity (cc)     10000 non-null  int64
#  7   Fuel Type                10000 non-null  object
#  8   Mileage (km/l)           10000 non-null  float64
#  9   Owner Type               10000 non-null  object
#  10  Registration Year        10000 non-null  int64
#  11  Insurance Status         10000 non-null  object
#  12  Seller Type              10000 non-null  object
#  13  Resale Price (INR)       10000 non-null  float64
# ...

# %%
df2.describe()
# Out:
#        Avg Daily Distance (km)    Price (INR)  Year of Manufacture  \
# count             10000.000000   10000.000000         10000.000000
# mean                 42.533128  224328.722400          2019.510500
# std                  21.676985  100753.660447             2.907668
# min                   5.010000   50031.000000          2015.000000
# 25%                  23.907500  137900.250000          2017.000000
# 50%                  42.480000  223878.000000          2019.000000
# 75%                  61.352500  311464.250000          2022.000000
# max                  80.000000  399981.000000          2024.000000
#
#        Engine Capacity (cc)  Mileage (km/l)  Registration Year  \
# count          10000.000000    10000.000000        10000.00000
# mean             552.695300       67.188926         2020.96510
# std              261.176292       20.891728            2.74897
# min              100.000000       25.000000         2015.00000
# ...

# %%
df2
# Out:
#                State  Avg Daily Distance (km)          Brand        Model  \
# 0          Karnataka                    68.84  Royal Enfield   Hunter 350
# 1          Rajasthan                    23.80          Bajaj  Dominar 400
# 2     Madhya Pradesh                    27.67            KTM     125 Duke
# 3          Karnataka                    62.85       Kawasaki    Ninja 300
# 4     Madhya Pradesh                    10.62         Yamaha        FZ V3
# ...              ...                      ...            ...          ...
# 9995         Gujarat                    67.72           Hero  Passion Pro
# 9996           Delhi                    19.94          Bajaj       CT 100
# 9997     West Bengal                    79.95          Bajaj   Pulsar 150
# 9998  Madhya Pradesh                    16.07          Honda          Dio
# 9999     West Bengal                    51.16  Royal Enfield  Classic 350
#
#       Price (INR) Year of Manufacture  Engine Capacity (cc) Fuel Type  \
# ...

# %%
df2[df2['Model']=='Interceptor 650']
# Out:
#               State  Avg Daily Distance (km)          Brand            Model  \
# 79            Delhi                    65.75  Royal Enfield  Interceptor 650
# 144           Delhi                    66.80  Royal Enfield  Interceptor 650
# 163   Uttar Pradesh                    16.10  Royal Enfield  Interceptor 650
# 194      Tamil Nadu                    52.45  Royal Enfield  Interceptor 650
# 240       Rajasthan                    21.39  Royal Enfield  Interceptor 650
# ...             ...                      ...            ...              ...
# 9667         Punjab                    41.07  Royal Enfield  Interceptor 650
# 9725    Maharashtra                    36.62  Royal Enfield  Interceptor 650
# 9788        Gujarat                    19.17  Royal Enfield  Interceptor 650
# 9808    West Bengal                    33.07  Royal Enfield  Interceptor 650
# 9983    West Bengal                    69.39  Royal Enfield  Interceptor 650
#
# ...

# %% [markdown]
# ## TASK 1 Data Cleaning ---  Engine Capacity (cc) and price is incorrect i would like to give a correct value using **ChatGPT** , because it will usefull for my **SQL** and **POWER BI Report**.

# %%
df2.loc[df2['Model'] == 'Ray ZR', ['Engine Capacity (cc)', 'Price (INR)']] = [125, 87000]
df2.loc[df2['Model'] == 'NTorq 125', ['Engine Capacity (cc)', 'Price (INR)']] = [125, 88500]
df2.loc[df2['Model'] == 'Duke 200', ['Engine Capacity (cc)', 'Price (INR)']] = [200, 196000]
df2.loc[df2['Model'] == '250 Duke', ['Engine Capacity (cc)', 'Price (INR)']] = [250, 240000]
df2.loc[df2['Model'] == 'Classic 350', ['Engine Capacity (cc)', 'Price (INR)']] = [349, 193000]
df2.loc[df2['Model'] == 'MT-15', ['Engine Capacity (cc)', 'Price (INR)']] = [155, 167000]
df2.loc[df2['Model'] == 'Vulcan S', ['Engine Capacity (cc)', 'Price (INR)']] = [649, 712000]
df2.loc[df2['Model'] == 'Interceptor 650', ['Engine Capacity (cc)', 'Price (INR)']] = [648, 304000]
df2.loc[df2['Model'] == 'Pulsar 150', ['Engine Capacity (cc)', 'Price (INR)']] = [149, 118000]
df2.loc[df2['Model'] == 'Versys 650', ['Engine Capacity (cc)', 'Price (INR)']] = [649, 777000]
df2.loc[df2['Model'] == 'Hunter 350', ['Engine Capacity (cc)', 'Price (INR)']] = [349, 149000]
df2.loc[df2['Model'] == 'Glamour', ['Engine Capacity (cc)', 'Price (INR)']] = [125, 87000]
df2.loc[df2['Model'] == 'Sport', ['Engine Capacity (cc)', 'Price (INR)']] = [100, 69500]
df2.loc[df2['Model'] == 'HF Deluxe', ['Engine Capacity (cc)', 'Price (INR)']] = [97, 59000]
df2.loc[df2['Model'] == 'Unicorn', ['Engine Capacity (cc)', 'Price (INR)']] = [162, 109000]
df2.loc[df2['Model'] == 'FZ V3', ['Engine Capacity (cc)', 'Price (INR)']] = [149, 116000]
df2.loc[df2['Model'] == 'Ninja 300', ['Engine Capacity (cc)', 'Price (INR)']] = [296, 343000]
df2.loc[df2['Model'] == 'Ninja 400', ['Engine Capacity (cc)', 'Price (INR)']] = [399, 534000]
df2.loc[df2['Model'] == '390 Adventure', ['Engine Capacity (cc)', 'Price (INR)']] = [373, 338000]
df2.loc[df2['Model'] == 'Z650', ['Engine Capacity (cc)', 'Price (INR)']] = [649, 656000]
df2.loc[df2['Model'] == 'Ronin', ['Engine Capacity (cc)', 'Price (INR)']] = [225, 150000]
df2.loc[df2['Model'] == 'Himalayan', ['Engine Capacity (cc)', 'Price (INR)']] = [411, 243000]
df2.loc[df2['Model'] == 'Avenger 220', ['Engine Capacity (cc)', 'Price (INR)']] = [220, 139000]
df2.loc[df2['Model'] == 'Xtreme 160R', ['Engine Capacity (cc)', 'Price (INR)']] = [163, 123000]
df2.loc[df2['Model'] == 'RC 390', ['Engine Capacity (cc)', 'Price (INR)']] = [373, 316000]
df2.loc[df2['Model'] == 'CBR 650R', ['Engine Capacity (cc)', 'Price (INR)']] = [648, 915000]
df2.loc[df2['Model'] == 'Fascino 125', ['Engine Capacity (cc)', 'Price (INR)']] = [125, 92000]
df2.loc[df2['Model'] == 'Passion Pro', ['Engine Capacity (cc)', 'Price (INR)']] = [110, 78000]
df2.loc[df2['Model'] == 'Shine', ['Engine Capacity (cc)', 'Price (INR)']] = [125, 83000]
df2.loc[df2['Model'] == 'Dio', ['Engine Capacity (cc)', 'Price (INR)']] = [110, 74000]
df2.loc[df2['Model'] == 'CT 100', ['Engine Capacity (cc)', 'Price (INR)']] = [102, 67000]
df2.loc[df2['Model'] == 'R15 V4', ['Engine Capacity (cc)', 'Price (INR)']] = [155, 181000]
df2.loc[df2['Model'] == 'Dominar 400', ['Engine Capacity (cc)', 'Price (INR)']] = [373, 247000]
df2.loc[df2['Model'] == '125 Duke', ['Engine Capacity (cc)', 'Price (INR)']] = [124, 180000]
df2.loc[df2['Model'] == 'Activa', ['Engine Capacity (cc)', 'Price (INR)']] = [110, 79000]
df2.loc[df2['Model'] == 'Splendor Plus', ['Engine Capacity (cc)', 'Price (INR)']] = [97, 75000]
df2.loc[df2['Model'] == 'Platina 110', ['Engine Capacity (cc)', 'Price (INR)']] = [115, 77000]
df2.loc[df2['Model'] == 'Apache RTR 160', ['Engine Capacity (cc)', 'Price (INR)']] = [159, 121000]
df2.loc[df2['Model'] == 'Jupiter', ['Engine Capacity (cc)', 'Price (INR)']] = [110, 87000]
df2.loc[df2['Model'] == 'Meteor 350', ['Engine Capacity (cc)', 'Price (INR)']] = [349, 202000]

# %%
df2
# Out:
#                State  Avg Daily Distance (km)          Brand        Model  \
# 0          Karnataka                    68.84  Royal Enfield   Hunter 350
# 1          Rajasthan                    23.80          Bajaj  Dominar 400
# 2     Madhya Pradesh                    27.67            KTM     125 Duke
# 3          Karnataka                    62.85       Kawasaki    Ninja 300
# 4     Madhya Pradesh                    10.62         Yamaha        FZ V3
# ...              ...                      ...            ...          ...
# 9995         Gujarat                    67.72           Hero  Passion Pro
# 9996           Delhi                    19.94          Bajaj       CT 100
# 9997     West Bengal                    79.95          Bajaj   Pulsar 150
# 9998  Madhya Pradesh                    16.07          Honda          Dio
# 9999     West Bengal                    51.16  Royal Enfield  Classic 350
#
#       Price (INR)  Year of Manufacture  Engine Capacity (cc) Fuel Type  \
# ...

# %%
df2['Model'].value_counts().count()
# Out:
# np.int64(40)

# %%
df2['Model'].value_counts()
# Out:
# Model
# Ray ZR             279
# NTorq 125          271
# Duke 200           270
# 250 Duke           269
# Classic 350        267
# MT-15              267
# Vulcan S           267
# Interceptor 650    264
# Pulsar 150         261
# Versys 650         261
# Hunter 350         259
# Glamour            258
# Sport              258
# HF Deluxe          257
# Unicorn            257
# FZ V3              256
# Ninja 300          256
# Ninja 400          255
# 390 Adventure      254
# Z650               252
# Ronin              252
# Himalayan          249
# Avenger 220        249
# Xtreme 160R        249
# RC 390             248
# CBR 650R           248
# Fascino 125        248
# Passion Pro        247
# Shine              244
# Dio                242
# CT 100             236
# R15 V4             233
# Dominar 400        233
# 125 Duke           231
# Activa             230
# Splendor Plus      228
# Platina 110        228
# Apache RTR 160     227
# Jupiter            226
# ...

# %% [markdown]
# Fuel Type and mileage also incorrect so im change it also

# %%
df2.loc[df2['Model'] == 'Ray ZR', ['Fuel Type', 'Mileage (km/l)']] = ['Petrol', 51]
df2.loc[df2['Model'] == 'NTorq 125', ['Fuel Type', 'Mileage (km/l)']] = ['Petrol', 42]
df2.loc[df2['Model'] == 'Duke 200', ['Fuel Type', 'Mileage (km/l)']] = ['Petrol', 33]
df2.loc[df2['Model'] == '250 Duke', ['Fuel Type', 'Mileage (km/l)']] = ['Petrol', 32]
df2.loc[df2['Model'] == 'Classic 350', ['Fuel Type', 'Mileage (km/l)']] = ['Petrol', 41.55]
df2.loc[df2['Model'] == 'MT-15', ['Fuel Type', 'Mileage (km/l)']] = ['Petrol', 46]
df2.loc[df2['Model'] == 'Vulcan S', ['Fuel Type', 'Mileage (km/l)']] = ['Petrol', 20.58]
df2.loc[df2['Model'] == 'Interceptor 650', ['Fuel Type', 'Mileage (km/l)']] = ['Petrol', 24]
df2.loc[df2['Model'] == 'Pulsar 150', ['Fuel Type', 'Mileage (km/l)']] = ['Petrol', 48]
df2.loc[df2['Model'] == 'Versys 650', ['Fuel Type', 'Mileage (km/l)']] = ['Petrol', 19.4]
df2.loc[df2['Model'] == 'Hunter 350', ['Fuel Type', 'Mileage (km/l)']] = ['Petrol', 36.22]
df2.loc[df2['Model'] == 'Glamour', ['Fuel Type', 'Mileage (km/l)']] = ['Petrol', 55]
df2.loc[df2['Model'] == 'Sport', ['Fuel Type', 'Mileage (km/l)']] = ['Petrol', 65]
df2.loc[df2['Model'] == 'HF Deluxe', ['Fuel Type', 'Mileage (km/l)']] = ['Petrol', 72.5]
df2.loc[df2['Model'] == 'Unicorn', ['Fuel Type', 'Mileage (km/l)']] = ['Petrol', 53.5]
df2.loc[df2['Model'] == 'FZ V3', ['Fuel Type', 'Mileage (km/l)']] = ['Petrol', 45]
df2.loc[df2['Model'] == 'Ninja 300', ['Fuel Type', 'Mileage (km/l)']] = ['Petrol', 25]
df2.loc[df2['Model'] == 'Ninja 400', ['Fuel Type', 'Mileage (km/l)']] = ['Petrol', 24]
df2.loc[df2['Model'] == '390 Adventure', ['Fuel Type', 'Mileage (km/l)']] = ['Petrol', 28]
df2.loc[df2['Model'] == 'Z650', ['Fuel Type', 'Mileage (km/l)']] = ['Petrol', 23]
df2.loc[df2['Model'] == 'Ronin', ['Fuel Type', 'Mileage (km/l)']] = ['Petrol', 40]
df2.loc[df2['Model'] == 'Himalayan', ['Fuel Type', 'Mileage (km/l)']] = ['Petrol', 30]
df2.loc[df2['Model'] == 'Avenger 220', ['Fuel Type', 'Mileage (km/l)']] = ['Petrol', 45]
df2.loc[df2['Model'] == 'Xtreme 160R', ['Fuel Type', 'Mileage (km/l)']] = ['Petrol', 55]
df2.loc[df2['Model'] == 'RC 390', ['Fuel Type', 'Mileage (km/l)']] = ['Petrol', 25]
df2.loc[df2['Model'] == 'CBR 650R', ['Fuel Type', 'Mileage (km/l)']] = ['Petrol', 20]
df2.loc[df2['Model'] == 'Fascino 125', ['Fuel Type', 'Mileage (km/l)']] = ['Petrol', 58]
df2.loc[df2['Model'] == 'Passion Pro', ['Fuel Type', 'Mileage (km/l)']] = ['Petrol', 60]
df2.loc[df2['Model'] == 'Shine', ['Fuel Type', 'Mileage (km/l)']] = ['Petrol', 55]
df2.loc[df2['Model'] == 'Dio', ['Fuel Type', 'Mileage (km/l)']] = ['Petrol', 48]
df2.loc[df2['Model'] == 'CT 100', ['Fuel Type', 'Mileage (km/l)']] = ['Petrol', 75]
df2.loc[df2['Model'] == 'R15 V4', ['Fuel Type', 'Mileage (km/l)']] = ['Petrol', 45]
df2.loc[df2['Model'] == 'Dominar 400', ['Fuel Type', 'Mileage (km/l)']] = ['Petrol', 27]
df2.loc[df2['Model'] == '125 Duke', ['Fuel Type', 'Mileage (km/l)']] = ['Petrol', 45]
df2.loc[df2['Model'] == 'Activa', ['Fuel Type', 'Mileage (km/l)']] = ['Petrol', 50]
df2.loc[df2['Model'] == 'Splendor Plus', ['Fuel Type', 'Mileage (km/l)']] = ['Petrol', 70]
df2.loc[df2['Model'] == 'Platina 110', ['Fuel Type', 'Mileage (km/l)']] = ['Petrol', 70]
df2.loc[df2['Model'] == 'Apache RTR 160', ['Fuel Type', 'Mileage (km/l)']] = ['Petrol', 45]
df2.loc[df2['Model'] == 'Jupiter', ['Fuel Type', ' Mileage (km/l)']] = ['Petrol', 50]
df2.loc[df2['Model'] == 'Meteor 350', ['Fuel Type', 'Mileage (km/l)']] = ['Petrol', 35]

# %%
df2[df2['Model']=='Interceptor 650']
# Out:
#               State  Avg Daily Distance (km)          Brand            Model  \
# 79            Delhi                    65.75  Royal Enfield  Interceptor 650
# 144           Delhi                    66.80  Royal Enfield  Interceptor 650
# 163   Uttar Pradesh                    16.10  Royal Enfield  Interceptor 650
# 194      Tamil Nadu                    52.45  Royal Enfield  Interceptor 650
# 240       Rajasthan                    21.39  Royal Enfield  Interceptor 650
# ...             ...                      ...            ...              ...
# 9667         Punjab                    41.07  Royal Enfield  Interceptor 650
# 9725    Maharashtra                    36.62  Royal Enfield  Interceptor 650
# 9788        Gujarat                    19.17  Royal Enfield  Interceptor 650
# 9808    West Bengal                    33.07  Royal Enfield  Interceptor 650
# 9983    West Bengal                    69.39  Royal Enfield  Interceptor 650
#
# ...

# %% [markdown]
# I dont want  Owner Type ,Seller Type , Insurance Status , Resale Price (INR)

# %%
 df2 = df2.drop(df2.columns[-1], axis=1)
df2=df2.drop('Owner Type',axis=1)

# %%
df2=df2.drop(['Seller Type','Insurance Status'],axis=1)

# %%
df2=df2.drop('Resale Price (INR)',axis=1)

# %%
df2=df2.drop('Registration Year',axis=1)

# %%
df2
# Out:
#                State  Avg Daily Distance (km)          Brand        Model  \
# 0          Karnataka                    68.84  Royal Enfield   Hunter 350
# 1          Rajasthan                    23.80          Bajaj  Dominar 400
# 2     Madhya Pradesh                    27.67            KTM     125 Duke
# 3          Karnataka                    62.85       Kawasaki    Ninja 300
# 4     Madhya Pradesh                    10.62         Yamaha        FZ V3
# ...              ...                      ...            ...          ...
# 9995         Gujarat                    67.72           Hero  Passion Pro
# 9996           Delhi                    19.94          Bajaj       CT 100
# 9997     West Bengal                    79.95          Bajaj   Pulsar 150
# 9998  Madhya Pradesh                    16.07          Honda          Dio
# 9999     West Bengal                    51.16  Royal Enfield  Classic 350
#
#       Price (INR) Year of Manufacture  Engine Capacity (cc) Fuel Type  \
# ...

# %%
df2.isna().sum()
# Out:
# State                         0
# Avg Daily Distance (km)       0
# Brand                         0
# Model                         0
# Price (INR)                   0
# Year of Manufacture           0
# Engine Capacity (cc)          0
# Fuel Type                     0
# Mileage (km/l)                0
# Registration Year             0
# City Tier                     0
#  Mileage (km/l)            9774
# dtype: int64

# %%
df2.dtypes
# Out:
# State                              object
# Avg Daily Distance (km)           float64
# Brand                              object
# Model                              object
# Price (INR)                         int64
# Year of Manufacture        datetime64[ns]
# Engine Capacity (cc)                int64
# Fuel Type                          object
# Mileage (km/l)                    float64
# Registration Year          datetime64[ns]
# dtype: object

# %%
df2['Year of Manufacture'	]=pd.to_datetime(df2['Year of Manufacture'],format='%Y')

# %%
df2['Registration Year']=pd.to_datetime(df2['Registration Year'],format='%Y')

# %%
df2.to_csv('bike_sales_cleaned.csv',index=False)

# %%
df2
# Out:
#                State  Avg Daily Distance (km)          Brand        Model  \
# 0          Karnataka                    68.84  Royal Enfield   Hunter 350
# 1          Rajasthan                    23.80          Bajaj  Dominar 400
# 2     Madhya Pradesh                    27.67            KTM     125 Duke
# 3          Karnataka                    62.85       Kawasaki    Ninja 300
# 4     Madhya Pradesh                    10.62         Yamaha        FZ V3
# ...              ...                      ...            ...          ...
# 9995         Gujarat                    67.72           Hero  Passion Pro
# 9996           Delhi                    19.94          Bajaj       CT 100
# 9997     West Bengal                    79.95          Bajaj   Pulsar 150
# 9998  Madhya Pradesh                    16.07          Honda          Dio
# 9999     West Bengal                    51.16  Royal Enfield  Classic 350
#
#       Price (INR) Year of Manufacture  Engine Capacity (cc) Fuel Type  \
# ...
